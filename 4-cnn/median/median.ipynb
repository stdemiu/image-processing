# %%
import numpy as np

x = np.array([[14, 18, 19], [24, 26, 33], [42, 55, 67]])

np.median(x)
from skimage.io import imread, imshow, imsave

img = imread('image.png')
imshow(img);

img.shape
k = 7
half = k // 2

half
n_rows, n_columns = (img.shape[0], img.shape[1])
out_img = np.zeros((n_rows, n_columns))

for i in range(half, n_rows - half):
    for j in range(half, n_columns - half):
        box = img[i - half: i + half + 1, j - half: j + half + 1]
        median = np.median(box)
        out_img[i, j] = median

out_img.min(), out_img.max()

out_img.dtype
out_img[3]
out_img = out_img[half:n_rows - half, half:n_columns - half].astype('uint8')
out_img

img_median = imread('image.png')

imshow(img_median);
np.array_equal(out_img, img_median)
imshow(out_img);
imsave('median-my.png', out_img)
# Out:
# C:\Users\stacy\AppData\Local\Temp\ipykernel_12832\1260765848.py:11: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(img);
# C:\Users\stacy\AppData\Local\Temp\ipykernel_12832\1260765848.py:43: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(img_median);
# C:\Users\stacy\AppData\Local\Temp\ipykernel_12832\1260765848.py:47: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(out_img);
