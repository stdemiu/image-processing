# %%
from skimage.io import imread, imshow, imsave

img = imread('image.jpg')

imshow(img);

from skimage import img_as_float, img_as_ubyte

img_f = img_as_float(img)
img_f.dtype
img_f

import numpy as np

r, g, b = np.dsplit(img_f, 3)
r.shape
r.size
r.ndim

r_avg, g_avg, b_avg = [np.mean(i) for i in (r, g, b)]
r_avg
g_avg
b_avg

avg = np.mean((r_avg, g_avg, b_avg))

avg

r_w, g_w, b_w = [i / avg for i in (r_avg, g_avg, b_avg)]
r_new = r / r_w
g_new = g / g_w
b_new = b / b_w

r_new.min(), r_new.max()

img_grey_world = np.dstack((r_new, g_new, b_new))
img_grey_world = np.clip(img_grey_world, 0, 1)

imshow(img_grey_world);

img_grey_world_final = img_as_ubyte(img_grey_world)

imsave('grey.jpg', img_grey_world_final)
# Out:
# C:\Users\stacy\AppData\Local\Temp\ipykernel_17944\2573993446.py:5: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(img);
# C:\Users\stacy\AppData\Local\Temp\ipykernel_17944\2573993446.py:39: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(img_grey_world);
